-- %% [markdown]
-- Bronze_Customer_Load

-- %% [markdown]
-- Bronze_Customer_Load

-- %%
%python
from pyspark.sql.functions import *
from datetime import datetime
from builtins import max as py_max
import re

landing_path = "s3a://generalretailsworkspace/landing/"

files = dbutils.fs.ls(landing_path)

customer_files = []

for file in files:

    if "customers-src" in file.name:

        match = re.search(r'(\d{8})_(\d{6})', file.name)

        if match:

            timestamp = datetime.strptime(
                match.group(1) + match.group(2),
                "%d%m%Y%H%M%S"
            )

            customer_files.append((file.path, timestamp))

latest_file = py_max(customer_files, key=lambda x: x[1])[0]

print("Latest Customer File:", latest_file)

bronze_table = "bronze_catalog.retail_bronze.bronze_customers"

df = (
    spark.read
    .option("header", True)
    .csv(latest_file)
)

df = df.withColumn("ingestion_time", current_timestamp()) \
       .withColumn("source_file", lit(latest_file))

df.write \
    .format("delta") \
    .mode("append") \
    .saveAsTable(bronze_table)

-- %% [markdown]
-- Bronze_Product_Load

-- %%
%python
from pyspark.sql.functions import *
from datetime import datetime
from builtins import max as py_max
import re

landing_path = "s3a://generalretailsworkspace/landing/"

files = dbutils.fs.ls(landing_path)

customer_files = []

for file in files:

    if "products-src" in file.name:

        match = re.search(r'(\d{8})_(\d{6})', file.name)

        if match:

            timestamp = datetime.strptime(
                match.group(1) + match.group(2),
                "%d%m%Y%H%M%S"
            )

            customer_files.append((file.path, timestamp))

latest_file = py_max(customer_files, key=lambda x: x[1])[0]

print("Latest Customer File:", latest_file)

bronze_table = "bronze_catalog.retail_bronze.bronze_products"

df = (
    spark.read
    .option("header", True)
    .csv(latest_file)
)

df = df.withColumn("ingestion_time", current_timestamp()) \
       .withColumn("source_file", lit(latest_file))

df.write \
    .format("delta") \
    .mode("append") \
    .saveAsTable(bronze_table)

-- %% [markdown]
-- Bronze_Store_Load

-- %%
%python
from pyspark.sql.functions import *
from datetime import datetime
from builtins import max as py_max
import re

landing_path = "s3a://generalretailsworkspace/landing/"

files = dbutils.fs.ls(landing_path)

customer_files = []

for file in files:

    if "stores-src" in file.name:

        match = re.search(r'(\d{8})_(\d{6})', file.name)

        if match:

            timestamp = datetime.strptime(
                match.group(1) + match.group(2),
                "%d%m%Y%H%M%S"
            )

            customer_files.append((file.path, timestamp))

latest_file = py_max(customer_files, key=lambda x: x[1])[0]

print("Latest Customer File:", latest_file)

bronze_table = "bronze_catalog.retail_bronze.stores"

df = (
    spark.read
    .option("header", True)
    .csv(latest_file)
)

df = df.withColumn("ingestion_time", current_timestamp()) \
       .withColumn("source_file", lit(latest_file))

df.write \
    .format("delta") \
    .mode("append") \
    .saveAsTable(bronze_table)

-- %% [markdown]
-- Bronze_Sales_Load

-- %%
%python
from pyspark.sql.functions import *
from datetime import datetime
from builtins import max as py_max
import re

landing_path = "s3a://generalretailsworkspace/landing/"

files = dbutils.fs.ls(landing_path)

customer_files = []

for file in files:

    if "sales-transactions" in file.name:

        match = re.search(r'(\d{8})_(\d{6})', file.name)

        if match:

            timestamp = datetime.strptime(
                match.group(1) + match.group(2),
                "%d%m%Y%H%M%S"
            )

            customer_files.append((file.path, timestamp))

latest_file = py_max(customer_files, key=lambda x: x[1])[0]

print("Latest Customer File:", latest_file)

bronze_table = "bronze_catalog.retail_bronze.bronze_sales"

df = (
    spark.read
    .option("header", True)
    .csv(latest_file)
)

df = df.withColumn("ingestion_time", current_timestamp()) \
       .withColumn("source_file", lit(latest_file))

df.write \
    .format("delta") \
    .mode("append") \
    .saveAsTable(bronze_table)

-- %%
SELECT
    CustomerID,
    City,
    StartDate,
    EndDate,
    IsActive

FROM gold_catalog.retail_gold.DimCustomer

WHERE CustomerID = 101;

-- %%
select count(*) from gold_catalog.retail_gold.DimCustomer;
